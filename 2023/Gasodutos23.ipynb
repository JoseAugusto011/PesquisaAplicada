# %%
import pandas as pd

# %%
d1 = pd.read_csv("gn-janeiro-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
d2 = pd.read_csv("gn-fevereiro-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
d3 = pd.read_csv("gn-marco-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
d4 = pd.read_csv("gn-abril-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_11968\3418058239.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   d1 = pd.read_csv("gn-janeiro-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_11968\3418058239.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   d2 = pd.read_csv("gn-fevereiro-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_11968\3418058239.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   d3 = pd.read_csv("gn-marco-2023.csv",encoding='latin-1', error_bad_lines=False, sep=';')
# ...

# %%
df23 = pd.concat([d1,d2,d3,d4],ignore_index=True)

# %%
df23.to_csv("gn-2023.csv", index=False, encoding='utf-8-sig')

# %%
df23.head(5)
# Out:
#    Código da Instalação de Transporte      Nome da Instalação de Transporte  \
# 0                              700521  Bolívia - Mato Grosso Lateral Cuiabá
# 1                              700521  Bolívia - Mato Grosso Lateral Cuiabá
# 2                              700521  Bolívia - Mato Grosso Lateral Cuiabá
# 3                              700521  Bolívia - Mato Grosso Lateral Cuiabá
# 4                              700521  Bolívia - Mato Grosso Lateral Cuiabá
#
#   Nome da Instalação de Gasoduto  Código da Instalação de Gasoduto  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
#
#   Tipo da instalação de Gasoduto Nome do Município da Instalação de Gasoduto  \
# ...
